# %% [markdown]
# **Notes and Reference**
#
# - This is my personal android dev learning notebook.
# - Study of `delayedPost()` and `Runnable`
#   - Coding in Flow (2018) Delay and Repeat Code Execution with Handler PostDelayed - Android Studio Tutorial https://www.youtube.com/watch?v=3pgGVBmSVq0&ab_channel=CodinginFlow

# %% [markdown]
# # `Java`

# %% [markdown]
# ## `postDelayed()`
# - Causes the `Runnable r` to be added to the `MessageQueue`, to be run after the specified amount of time elapses. The `Runnable` will be run on the `Thread` to which this `Handler` is attached. The time-base is `SystemClock.uptimeMillis`. Time spent in deep sleep will add an additional delay to execution.

# %%
path = "/content/here/MyDrive/Android/postDelayed/Java/postDelayed.png"
show_img(path, resize=(1, 1))
# Out:
# <PIL.Image.Image image mode=RGB size=538x169 at 0x7FB9FF6C0E90>

# %% [markdown]
# ## Result

# %%
path = "/content/here/MyDrive/Android/postDelayed/Java/result.png"
show_img(path, resize=(0.7, 0.7))
# Out:
# <PIL.Image.Image image mode=RGB size=736x654 at 0x7FB9F00C4690>

# %% [markdown]
# # Error Notes

# %% [markdown]
# ## `@string` resource and hard coding

# %%
path = "/content/here/MyDrive/Android/postDelayed/Java/error1 button not constraint.png"
show_img(path, resize=None)
# Out:
# <PIL.Image.Image image mode=RGB size=782x509 at 0x7FB9EFFE7450>
