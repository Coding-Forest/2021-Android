# %% [markdown]
# **Notes and Reference**
#
# Minion from Wikimedia Commons, the free media repository
#
# https://commons.wikimedia.org/wiki/File:Minion_(example).svg
# This is my personal android dev learning notebook.
#
# The majority of the source code from an animated Splash tutorial by Android Coding. Link to the original tutorial is provided below. Have fun learning :) !
#
# Android Coding (2020) How to Implement Animated Splash Screen in Android Studio | AnimatedSplashScreen | Android Coding https://www.youtube.com/watch?v=OARIq17u12g&ab_channel=AndroidCoding

# %% [markdown]
# # 1 UI testing

# %% [markdown]
# ## `fromYdelta="100%`
#
# `<translate>`
#
# - In `Animation Resource File`:
#     - All the way down at the bottom of the y coordinate.
#
# `</translate>`

# %%
path = "/content/here/MyDrive/Android/Splash Animated - Testing/UI/20211008_173458.jpg"
show_img(path, resize=(0.3, 0.3))
# Out:
# <PIL.Image.Image image mode=RGB size=324x666 at 0x7F32E939EC10>

# %% [markdown]
# ## `fromYdelta="-50%`
#
# `<translate>`
#
# - In `Animation Resource File`:
#     - The minus sign (-) in `-50%` changes the direction, descending from top to bottom.
#
# `</translate>`

# %%
path = "/content/here/MyDrive/Android/Splash Animated - Testing/UI/20211008_173402.jpg"
show_img(path, resize=(0.3, 0.3))
# Out:
# <PIL.Image.Image image mode=RGB size=324x666 at 0x7F32E939EE90>

# %% [markdown]
# ## `layout_width` & and `layout_height`

# %%
path = "/content/here/MyDrive/Android/Splash Animated - Testing/UI/20211008_185422.jpg"
show_img(path, resize=(0.3, 0.3))
# Out:
# <PIL.Image.Image image mode=RGB size=324x666 at 0x7F32E937B1D0>

# %% [markdown]
# ## Typing effect with `index++`
# - `TextView.setText(charSequence.subSequence(0, index++));`

# %%
path = "/content/here/MyDrive/Android/Splash Animated - Testing/UI/20211008_190218.jpg"
show_img(path, resize=(0.3, 0.3))
# Out:
# <PIL.Image.Image image mode=RGB size=324x666 at 0x7F32E93DC710>

# %% [markdown]
# ## `z-index` in Android

# %%
path = "/content/here/MyDrive/Android/Splash Animated - Testing/UI/20211008_191159.jpg"
show_img(path, resize=(0.3, 0.3))
# Out:
# <PIL.Image.Image image mode=RGB size=324x666 at 0x7F32EDCB14D0>

# %% [markdown]
# ## Align text in the centre

# %%
path = "/content/here/MyDrive/Android/Splash Animated - Testing/UI/20211008_200120.jpg"
show_img(path, resize=(0.3, 0.3))
# Out:
# <PIL.Image.Image image mode=RGB size=324x666 at 0x7F32E9353A10>

# %% [markdown]
# ## `layout_height="match_parent"` & `layout_marginTop="70dp"`
# - When your element doesn't want to get down to Earth...

# %%
path = "/content/here/MyDrive/Android/Splash Animated - Testing/UI/20211008_202243.jpg"
show_img(path, resize=(0.3, 0.3))
# Out:
# <PIL.Image.Image image mode=RGB size=324x666 at 0x7F32E93CBA50>

# %% [markdown]
# # 2 Java

# %% [markdown]
# ## `getSupportActionBar().hide()`

# %%
# in SplashActivity.java, 

public class SplashActivity extends AppCompatActivity {

    @Override
    protected void onCreate(Bundle savedInstanceState) {
        super.onCreate(savedInstanceState);
        setContentView(R.layout.activity_splash);

        getSupportActionBar().hide();   # hide your actionBar

# %%
path = "/content/here/MyDrive/Android/Splash Animated - Testing/UI/20211008_195417.jpg"
show_img(path, resize=(0.3, 0.3))
# Out:
# <PIL.Image.Image image mode=RGB size=324x666 at 0x7F32E93D6A50>
