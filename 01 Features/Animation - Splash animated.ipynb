# %% [markdown]
# **Notes and Reference**
#
# This is my personal android dev learning notebook.
#
# The majority of the source code from an animated Splash tutorial by Android Coding. Link to the original tutorial is provided below. Have fun learning :) !
#
# - Android Coding (2020) How to Implement Animated Splash Screen in Android Studio | AnimatedSplashScreen | Android Coding https://www.youtube.com/watch?v=OARIq17u12g&ab_channel=AndroidCoding

# %% [markdown]
# # 0 Setting

# %% [markdown]
# ## Dependency setting - import `glide` in gradle

# %%
path = "/content/here/MyDrive/Android/Splash Animated/UI/00 dependency setting.png"
nt.show_img(path)
# Out:
# <PIL.Image.Image image mode=RGB size=970x1882 at 0x7FB0C49E0350>

# %% [markdown]
# # 1 UI

# %% [markdown]
# ## `adjustviewBounds="true"`

# %%
path = "/content/here/MyDrive/Android/Splash Animated/UI/01 adjust viewbounds.png"
nt.show_img(path)
# Out:
# <PIL.Image.Image image mode=RGB size=353x167 at 0x7FB0D0F98790>

# %% [markdown]
# ## `app:tint="colour hexcode"`
# - Changes the colour of vector asset.

# %%
path = "/content/here/MyDrive/Android/Splash Animated/UI/02 tint - change vector colour.png"
nt.show_img(path)
# Out:
# <PIL.Image.Image image mode=RGB size=721x575 at 0x7FB0C49BFB50>

# %% [markdown]
# ## Create `anim` resources
# - Create an `Android Resource File` of resource type `Animation`, and the Studio will automatically create a `resource directory` called `anim` for you.

# %%
path = "/content/here/MyDrive/Android/Splash Animated/UI/03 resource file - Animation.png"
nt.show_img(path)
# Out:
# <PIL.Image.Image image mode=RGB size=827x725 at 0x7FB0C49C6450>

# %% [markdown]
# # 2 `Java`

# %% [markdown]
# ## `.loadAnimation()`
# Animates an object according to an `.xml` script instructing the animation details.

# %% [markdown]
# ### `Android Resource File`
# - `[App] - [New] - [Android Resource File]` to animate a UI element (in `.xml`)

# %%
# SplashScreen.java
public class SplashScreen extends AppCompatActivity {

    ImageView IVheart, IVheartbeat, IVbottom;
    TextView TVappname;

    @Override
    protected void onCreate(Bundle savedInstanceState) {
        super.onCreate(savedInstanceState);
        setContentView(R.layout.activity_splash_screen);

        ...

        // Initialise top animation
        Animation anim_top = AnimationUtils.loadAnimation(this,);
        # and now go create the Android Resource File for this anim_top element.

# %%
# top_wave.xml

<?xml version="1.0" encoding="utf-8"?>
<set xmlns:android="http://schemas.android.com/apk/res/android">

    <translate
        android:fromXDelta="-50%"
        android:fromYDelta="0%"
        android:duration="2500"
        />
    <alpha
        android:fromAlpha="1.0"
        android:toAlpha="0.5"
        android:duration="2500"
        />

</set>

# %%
# After creating the Android Resource File (top_wave.xml), 
# load it in .loadAnimation() with the Resource identifier (R.anim.top_wave).
        // Initialise top animation
        Animation anim_top = AnimationUtils.loadAnimation(this, R.anim.top_wave);
        // Start animation.
        IVtop.setAnimation(anim_top);
