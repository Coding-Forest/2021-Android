# %% [markdown]
# **Notes and Reference**
#
# This is my personal android dev learning notebook.
#
# The majority of the code from a handler video tutorial by Coding in flow. Link to the original tutorial is provided below. Have fun learning :) !
#
# - Coding in Flow (2018) How to Start a Background Thread in Android https://www.youtube.com/watch?v=QfQE1ayCzf8&ab_channel=CodinginFlow

# %% [markdown]
# # 1 UI

# %% [markdown]
# ## Splash
# - It is a basic one-off opening animation feature that displays when the app starts.

# %%
ui_files = ['20211006_211944.jpg', '20211006_211809.jpg', '20211006_212412.jpg', '20211006_213330.jpg', '20211006_212725.jpg', '20211006_214612.jpg']
for ui in ui_files:
    path = nt.ROOT_DIR + f'Splash/UI/{ui}'
    nt.show_img(path, resize=(0.35, 0.35))
    print('')
# Out:
# <PIL.Image.Image image mode=RGB size=777x378 at 0x7F995CBB8A50>
# <PIL.Image.Image image mode=RGB size=777x378 at 0x7F995CBC9FD0>
# <PIL.Image.Image image mode=RGB size=777x378 at 0x7F995CC4D390>
# <PIL.Image.Image image mode=RGB size=777x378 at 0x7F99582AF850>
# <PIL.Image.Image image mode=RGB size=777x378 at 0x7F9958246F10>
# <PIL.Image.Image image mode=RGB size=777x378 at 0x7F9958246290>

# %% [markdown]
# # 2 `Java`

# %% [markdown]
# ### `activity_splash_screen.xml`

# %%
# logo design by TravisAvery from Flaticon 
# The face logo used just for the learning & splash function demo purpose.
# Out:
# <PIL.Image.Image image mode=RGB size=777x657 at 0x7F30DCE81B50>

# %% [markdown]
# ## `SplashScreen.java`
# - In `SplashScreen.java`, write the logic to display the Splash as an opening animation.

# %%
# SplashScreen.java

package com.example.splashscreen;

import androidx.appcompat.app.AppCompatActivity;

import android.content.Intent;
import android.os.Bundle;
import android.os.Handler;

public class SplashScreen extends AppCompatActivity {

    @Override
    protected void onCreate(Bundle savedInstanceState) {
        super.onCreate(savedInstanceState);
        setContentView(R.layout.activity_splash_screen);

        new Handler().postDelayed(new Runnable() {
            @Override
            public void run() {

                Intent i = new Intent(SplashScreen.this, MainActivity.class);
                startActivity(i);
                finish();
            }
        }, 3000);
    }
}

# %% [markdown]
# ## `AndroidManifest.xml`

# %%
<?xml version="1.0" encoding="utf-8"?>
<manifest xmlns:android="http://schemas.android.com/apk/res/android"
    package="com.example.splashscreen">

    <application
        android:allowBackup="true"
        android:icon="@mipmap/ic_launcher"
        android:label="@string/app_name"
        android:roundIcon="@mipmap/ic_launcher_round"
        android:supportsRtl="true"
        android:theme="@style/Theme.SplashScreen">  # Add this

        <activity   # Add this activity with these detail
            android:name=".MainActivity"
            android:exported="true">
            <intent-filter>
                <action android:name="android.intent.action.MAIN" />

                <category android:name="android.intent.category.DEFAULT" /> # category should be default.
            </intent-filter>
        </activity>

        <activity     
            android:name=".SplashScreen"
            android:exported="true"
            android:theme="@style/Theme.AppCompat.DayNight.NoActionBar">
            <intent-filter>
                <action android:name="android.intent.action.MAIN" />

                <category android:name="android.intent.category.LAUNCHER" />
            </intent-filter>
        </activity>

    </application>

</manifest>
